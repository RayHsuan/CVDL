# %% [markdown]
# ### 作業
# 請嘗試使用 flip (左右翻轉) 來做 augmentation 以降低人臉關鍵點檢測的 loss
#
# Note: 圖像 flip 之後，groundtruth 的關鍵點也要跟著 flip 哦

# %% [markdown]
# ### 範例
# 接下來的程式碼會示範如何定義一個簡單的 CNN model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
data = pd.read_csv('G:/GitHub/CVDL/data/training/training.csv')

# %%
# 使用 colab 環境的同學請執行以下程式碼
# %tensorflow_version 1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2
# import tensorflow as tf
# print(tf.__version__)

# import os
# from google.colab import drive 
# drive.mount('/content/gdrive') # 將 google drive 掛載在 colob，
# %cd 'gdrive/My Drive'
# os.system("mkdir cupoy_cv_part4") # 可以自己改路徑
# %cd cupoy_cv_part4 # 可以自己改路徑

# %%
cols = list(data.columns)
print(cols)
# Out:
# ['left_eye_center_x', 'left_eye_center_y', 'right_eye_center_x', 'right_eye_center_y', 'left_eye_inner_corner_x', 'left_eye_inner_corner_y', 'left_eye_outer_corner_x', 'left_eye_outer_corner_y', 'right_eye_inner_corner_x', 'right_eye_inner_corner_y', 'right_eye_outer_corner_x', 'right_eye_outer_corner_y', 'left_eyebrow_inner_end_x', 'left_eyebrow_inner_end_y', 'left_eyebrow_outer_end_x', 'left_eyebrow_outer_end_y', 'right_eyebrow_inner_end_x', 'right_eyebrow_inner_end_y', 'right_eyebrow_outer_end_x', 'right_eyebrow_outer_end_y', 'nose_tip_x', 'nose_tip_y', 'mouth_left_corner_x', 'mouth_left_corner_y', 'mouth_right_corner_x', 'mouth_right_corner_y', 'mouth_center_top_lip_x', 'mouth_center_top_lip_y', 'mouth_center_bottom_lip_x', 'mouth_center_bottom_lip_y', 'Image']

# %%
# 讀取資料集以及做前處理的函數
def load_data(dirname):
    # 讀取 csv 文件
    data = pd.read_csv(dirname)
    # 過濾有缺失值的 row
    data = data.dropna()

    # 將圖片像素值讀取為 numpy array 的形態
    data['Image'] = data['Image'].apply(lambda img: np.fromstring(img, sep=' ')).values 

    # 單獨把圖像 array 抽取出來
    imgs = np.vstack(data['Image'].values)/255
    # reshape 為 96 x 96
    imgs = imgs.reshape(data.shape[0], 96, 96)
    # 轉換為 float
    imgs = imgs.astype(np.float32)
    
    # 提取坐標的部分
    points = data[data.columns[:-1]].values

    # 轉換為 float
    points = points.astype(np.float32)

    # normalize 坐標值到 [-0.5, 0.5]
    points = points/96 - 0.5
    
    return imgs, points

# %%
# 讀取資料
imgs_train, points_train = load_data(dirname = 'G:/GitHub/CVDL/data/training/training.csv')
print("圖像資料:", imgs_train.shape, "\n關鍵點資料:", points_train.shape)
# Out:
# 圖像資料: (2140, 96, 96)
# 關鍵點資料: (2140, 30)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
# Out:
# Using TensorFlow backend.

# %%
# 回傳定義好的 model 的函數
def get_model():
    # 定義人臉關鍵點檢測網路
    model = Sequential()

    # 定義神經網路的輸入
    model.add(Conv2D(filters=16, kernel_size=3, activation='relu', input_shape=(96, 96, 1)))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))

    # 最後輸出 30 維的向量，也就是 15 個關鍵點的值
    model.add(Dense(30))
    return model

# %%
model = get_model()
# 配置 loss funtion 和 optimizer
model.compile(loss='mean_squared_error', optimizer='adam')
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0209 19:08:47.362165  9476 deprecation_wrapper.py:119] From C:\Users\User\Anaconda3\envs\tensorflow\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0209 19:08:47.392085  9476 deprecation_wrapper.py:119] From C:\Users\User\Anaconda3\envs\tensorflow\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0209 19:08:47.402059  9476 deprecation_wrapper.py:119] From C:\Users\User\Anaconda3\envs\tensorflow\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0209 19:08:47.425021  9476 deprecation_wrapper.py:119] From C:\Users\User\Anaconda3\envs\tensorflow\lib\site-packages\keras\backend\tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# W0209 19:08:47.500794  9476 deprecation_wrapper.py:119] From C:\Users\User\Anaconda3\envs\tensorflow\lib\site-packages\keras\backend\tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# W0209 19:08:47.507776  9476 deprecation.py:506] From C:\Users\User\Anaconda3\envs\tensorflow\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0209 19:08:47.566618  9476 deprecation_wrapper.py:119] From C:\Users\User\Anaconda3\envs\tensorflow\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
# 印出網路結構
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 94, 94, 16)        160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 47, 47, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 30)                15390
# =================================================================
# Total params: 1,424,286
# Trainable params: 1,424,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, History
# model checkpoint 
checkpoint = ModelCheckpoint('best_weights.h5', verbose=1, save_best_only=True)
hist = History()

# %%
# training the model
hist_model = model.fit(imgs_train.reshape(-1, 96, 96, 1), 
                       points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=150, verbose=1)
# save the model weights
model.save_weights('weights.h5')
# save the model
model.save('model.h5')
# Out:
# W0209 19:09:11.727810  9476 deprecation_wrapper.py:119] From C:\Users\User\Anaconda3\envs\tensorflow\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
# Train on 1712 samples, validate on 428 samples
# Epoch 1/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 0.0069 - val_loss: 0.0027
#
# Epoch 00001: val_loss improved from inf to 0.00269, saving model to best_weights.h5
# Epoch 2/150
# 1712/1712 [==============================] - 0s 197us/step - loss: 0.0021 - val_loss: 0.0021
#
# Epoch 00002: val_loss improved from 0.00269 to 0.00210, saving model to best_weights.h5
# Epoch 3/150
# 1712/1712 [==============================] - 0s 196us/step - loss: 0.0014 - val_loss: 0.0019
#
# Epoch 00003: val_loss improved from 0.00210 to 0.00192, saving model to best_weights.h5
# Epoch 4/150
# 1712/1712 [==============================] - 0s 199us/step - loss: 0.0013 - val_loss: 0.0019
#
# Epoch 00004: val_loss did not improve from 0.00192
# Epoch 5/150
# 1712/1712 [==============================] - 0s 196us/step - loss: 0.0012 - val_loss: 0.0018
#
# Epoch 00005: val_loss improved from 0.00192 to 0.00184, saving model to best_weights.h5
# Epoch 6/150
# 1712/1712 [==============================] - 0s 203us/step - loss: 0.0011 - val_loss: 0.0018
#
# Epoch 00006: val_loss improved from 0.00184 to 0.00182, saving model to best_weights.h5
# Epoch 7/150
# 1712/1712 [==============================] - 0s 195us/step - loss: 9.6270e-04 - val_loss: 0.0017
#
# Epoch 00007: val_loss improved from 0.00182 to 0.00174, saving model to best_weights.h5
# Epoch 8/150
# 1712/1712 [==============================] - 0s 200us/step - loss: 8.2317e-04 - val_loss: 0.0016
#
# Epoch 00008: val_loss improved from 0.00174 to 0.00162, saving model to best_weights.h5
# Epoch 9/150
# 1712/1712 [==============================] - 0s 198us/step - loss: 7.6088e-04 - val_loss: 0.0015
#
# Epoch 00009: val_loss improved from 0.00162 to 0.00153, saving model to best_weights.h5
# Epoch 10/150
# 1712/1712 [==============================] - 0s 193us/step - loss: 6.5699e-04 - val_loss: 0.0015
#
# Epoch 00010: val_loss improved from 0.00153 to 0.00148, saving model to best_weights.h5
# Epoch 11/150
# 1712/1712 [==============================] - 0s 193us/step - loss: 5.9373e-04 - val_loss: 0.0013
#
# Epoch 00011: val_loss improved from 0.00148 to 0.00128, saving model to best_weights.h5
# Epoch 12/150
# 1712/1712 [==============================] - 0s 193us/step - loss: 5.6278e-04 - val_loss: 0.0013
#
# Epoch 00012: val_loss improved from 0.00128 to 0.00127, saving model to best_weights.h5
# Epoch 13/150
# 1712/1712 [==============================] - 0s 194us/step - loss: 5.0941e-04 - val_loss: 0.0012
#
# Epoch 00013: val_loss improved from 0.00127 to 0.00115, saving model to best_weights.h5
# Epoch 14/150
# 1712/1712 [==============================] - 0s 193us/step - loss: 4.6632e-04 - val_loss: 0.0012
#
# Epoch 00014: val_loss improved from 0.00115 to 0.00115, saving model to best_weights.h5
# Epoch 15/150
# 1712/1712 [==============================] - 0s 194us/step - loss: 4.3916e-04 - val_loss: 0.0011
#
# Epoch 00015: val_loss improved from 0.00115 to 0.00106, saving model to best_weights.h5
# Epoch 16/150
# 1712/1712 [==============================] - 0s 193us/step - loss: 4.1794e-04 - val_loss: 0.0010
#
# Epoch 00016: val_loss improved from 0.00106 to 0.00103, saving model to best_weights.h5
# Epoch 17/150
# 1712/1712 [==============================] - 0s 199us/step - loss: 3.9016e-04 - val_loss: 0.0010
#
# Epoch 00017: val_loss did not improve from 0.00103
# Epoch 18/150
# 1712/1712 [==============================] - 0s 193us/step - loss: 3.7588e-04 - val_loss: 0.0010
#
# Epoch 00018: val_loss improved from 0.00103 to 0.00101, saving model to best_weights.h5
# Epoch 19/150
# 1712/1712 [==============================] - 0s 200us/step - loss: 3.6939e-04 - val_loss: 0.0010
#
# Epoch 00019: val_loss did not improve from 0.00101
# Epoch 20/150
# 1712/1712 [==============================] - 0s 193us/step - loss: 3.5432e-04 - val_loss: 9.4776e-04
#
# Epoch 00020: val_loss improved from 0.00101 to 0.00095, saving model to best_weights.h5
# Epoch 21/150
# 1712/1712 [==============================] - 0s 199us/step - loss: 3.3354e-04 - val_loss: 9.7558e-04
#
# Epoch 00021: val_loss did not improve from 0.00095
# Epoch 22/150
# 1712/1712 [==============================] - 0s 194us/step - loss: 3.2364e-04 - val_loss: 9.6462e-04
#
# Epoch 00022: val_loss did not improve from 0.00095
# Epoch 23/150
# 1712/1712 [==============================] - 0s 194us/step - loss: 3.1743e-04 - val_loss: 9.9209e-04
#
# Epoch 00023: val_loss did not improve from 0.00095
# Epoch 24/150
# 1712/1712 [==============================] - 0s 194us/step - loss: 3.0581e-04 - val_loss: 8.9532e-04
#
# Epoch 00024: val_loss improved from 0.00095 to 0.00090, saving model to best_weights.h5
# Epoch 25/150
# 1712/1712 [==============================] - 0s 195us/step - loss: 2.9262e-04 - val_loss: 8.7393e-04
#
# Epoch 00025: val_loss improved from 0.00090 to 0.00087, saving model to best_weights.h5
# Epoch 26/150
# 1712/1712 [==============================] - 0s 194us/step - loss: 2.9731e-04 - val_loss: 9.0726e-04
#
# Epoch 00026: val_loss did not improve from 0.00087
# Epoch 27/150
# 1712/1712 [==============================] - 0s 197us/step - loss: 2.8404e-04 - val_loss: 9.0161e-04
#
# Epoch 00027: val_loss did not improve from 0.00087
# Epoch 28/150
# 1712/1712 [==============================] - 0s 197us/step - loss: 2.8067e-04 - val_loss: 9.1159e-04
#
# Epoch 00028: val_loss did not improve from 0.00087
# Epoch 29/150
# 1712/1712 [==============================] - 0s 195us/step - loss: 2.7692e-04 - val_loss: 8.7258e-04
#
# Epoch 00029: val_loss improved from 0.00087 to 0.00087, saving model to best_weights.h5
# Epoch 30/150
# 1712/1712 [==============================] - 0s 196us/step - loss: 2.5324e-04 - val_loss: 9.3071e-04
#
# Epoch 00030: val_loss did not improve from 0.00087
# Epoch 31/150
# 1712/1712 [==============================] - 0s 195us/step - loss: 2.6342e-04 - val_loss: 8.5316e-04
#
# Epoch 00031: val_loss improved from 0.00087 to 0.00085, saving model to best_weights.h5
# Epoch 32/150
# 1712/1712 [==============================] - 0s 195us/step - loss: 2.5853e-04 - val_loss: 8.4203e-04
#
# Epoch 00032: val_loss improved from 0.00085 to 0.00084, saving model to best_weights.h5
# Epoch 33/150
# 1712/1712 [==============================] - 0s 192us/step - loss: 2.5457e-04 - val_loss: 9.0366e-04
#
# Epoch 00033: val_loss did not improve from 0.00084
# Epoch 34/150
# 1712/1712 [==============================] - 0s 194us/step - loss: 2.4974e-04 - val_loss: 9.2214e-04
#
# Epoch 00034: val_loss did not improve from 0.00084
# Epoch 35/150
# 1712/1712 [==============================] - 0s 198us/step - loss: 2.4532e-04 - val_loss: 8.5950e-04
#
# Epoch 00035: val_loss did not improve from 0.00084
# Epoch 36/150
# 1712/1712 [==============================] - 0s 194us/step - loss: 2.4380e-04 - val_loss: 8.2915e-04
#
# Epoch 00036: val_loss improved from 0.00084 to 0.00083, saving model to best_weights.h5
# Epoch 37/150
# 1712/1712 [==============================] - 0s 193us/step - loss: 2.3552e-04 - val_loss: 8.6161e-04
#
# Epoch 00037: val_loss did not improve from 0.00083
# Epoch 38/150
# 1712/1712 [==============================] - 0s 193us/step - loss: 2.2850e-04 - val_loss: 8.5760e-04
#
# Epoch 00038: val_loss did not improve from 0.00083
# Epoch 39/150
# 1712/1712 [==============================] - 0s 192us/step - loss: 2.2339e-04 - val_loss: 8.5467e-04
#
# Epoch 00039: val_loss did not improve from 0.00083
# Epoch 40/150
# 1712/1712 [==============================] - 0s 195us/step - loss: 2.1530e-04 - val_loss: 8.8945e-04
#
# Epoch 00040: val_loss did not improve from 0.00083
# Epoch 41/150
# 1712/1712 [==============================] - 0s 194us/step - loss: 2.1917e-04 - val_loss: 8.9056e-04
#
# Epoch 00041: val_loss did not improve from 0.00083
# Epoch 42/150
# 1712/1712 [==============================] - 0s 195us/step - loss: 2.0840e-04 - val_loss: 8.6949e-04
#
# Epoch 00042: val_loss did not improve from 0.00083
# Epoch 43/150
# 1712/1712 [==============================] - 0s 203us/step - loss: 2.0343e-04 - val_loss: 8.7508e-04
#
# Epoch 00043: val_loss did not improve from 0.00083
# Epoch 44/150
# 1712/1712 [==============================] - 0s 196us/step - loss: 2.0517e-04 - val_loss: 9.1066e-04
#
# Epoch 00044: val_loss did not improve from 0.00083
# Epoch 45/150
# 1712/1712 [==============================] - 0s 204us/step - loss: 2.0640e-04 - val_loss: 8.2030e-04
# Epoch 00045: val_loss improved from 0.00083 to 0.00082, saving model to best_weights.h5
# Epoch 46/150
# 1712/1712 [==============================] - 0s 198us/step - loss: 2.0335e-04 - val_loss: 8.6250e-04
#
# Epoch 00046: val_loss did not improve from 0.00082
# Epoch 47/150
# 1712/1712 [==============================] - 0s 204us/step - loss: 1.9648e-04 - val_loss: 8.4183e-04
#
# Epoch 00047: val_loss did not improve from 0.00082
# Epoch 48/150
# 1712/1712 [==============================] - 0s 191us/step - loss: 1.9372e-04 - val_loss: 8.7503e-04
#
# Epoch 00048: val_loss did not improve from 0.00082
# Epoch 49/150
# 1712/1712 [==============================] - 0s 198us/step - loss: 1.8701e-04 - val_loss: 8.2832e-04
#
# Epoch 00049: val_loss did not improve from 0.00082
# Epoch 50/150
# 1712/1712 [==============================] - 0s 200us/step - loss: 1.8739e-04 - val_loss: 8.3885e-04
#
# Epoch 00050: val_loss did not improve from 0.00082
# Epoch 51/150
# 1712/1712 [==============================] - 0s 198us/step - loss: 1.8878e-04 - val_loss: 8.4180e-04
#
# Epoch 00051: val_loss did not improve from 0.00082
# Epoch 52/150
# 1712/1712 [==============================] - 0s 194us/step - loss: 1.8597e-04 - val_loss: 8.4108e-04
#
# Epoch 00052: val_loss did not improve from 0.00082
# Epoch 53/150
# 1712/1712 [==============================] - 0s 200us/step - loss: 1.8867e-04 - val_loss: 8.5731e-04
#
# Epoch 00053: val_loss did not improve from 0.00082
# Epoch 54/150
# 1712/1712 [==============================] - 0s 199us/step - loss: 1.8084e-04 - val_loss: 8.3817e-04
#
# Epoch 00054: val_loss did not improve from 0.00082
# Epoch 55/150
# 1712/1712 [==============================] - 0s 196us/step - loss: 1.7637e-04 - val_loss: 8.3945e-04
#
# Epoch 00055: val_loss did not improve from 0.00082
# Epoch 56/150
# 1712/1712 [==============================] - 0s 213us/step - loss: 1.7331e-04 - val_loss: 8.1671e-04
#
# Epoch 00056: val_loss improved from 0.00082 to 0.00082, saving model to best_weights.h5
# Epoch 57/150
# 1712/1712 [==============================] - 0s 197us/step - loss: 1.7091e-04 - val_loss: 8.2601e-04
#
# Epoch 00057: val_loss did not improve from 0.00082
# Epoch 58/150
# 1712/1712 [==============================] - 0s 198us/step - loss: 1.7373e-04 - val_loss: 8.1787e-04
#
# Epoch 00058: val_loss did not improve from 0.00082
# Epoch 59/150
# 1712/1712 [==============================] - 0s 196us/step - loss: 1.6984e-04 - val_loss: 8.7160e-04
#
# Epoch 00059: val_loss did not improve from 0.00082
# Epoch 60/150
# 1712/1712 [==============================] - 0s 199us/step - loss: 1.7020e-04 - val_loss: 8.1090e-04
#
# Epoch 00060: val_loss improved from 0.00082 to 0.00081, saving model to best_weights.h5
# Epoch 61/150
# 1712/1712 [==============================] - 0s 197us/step - loss: 1.7002e-04 - val_loss: 8.0826e-04
#
# Epoch 00061: val_loss improved from 0.00081 to 0.00081, saving model to best_weights.h5
# Epoch 62/150
# 1712/1712 [==============================] - 0s 192us/step - loss: 1.6844e-04 - val_loss: 8.5565e-04
#
# Epoch 00062: val_loss did not improve from 0.00081
# Epoch 63/150
# 1712/1712 [==============================] - 0s 201us/step - loss: 1.6799e-04 - val_loss: 8.0008e-04
#
# Epoch 00063: val_loss improved from 0.00081 to 0.00080, saving model to best_weights.h5
# Epoch 64/150
# 1712/1712 [==============================] - 0s 200us/step - loss: 1.6327e-04 - val_loss: 8.2396e-04
#
# Epoch 00064: val_loss did not improve from 0.00080
# Epoch 65/150
# 1712/1712 [==============================] - 0s 200us/step - loss: 1.5872e-04 - val_loss: 8.3599e-04
#
# Epoch 00065: val_loss did not improve from 0.00080
# Epoch 66/150
# 1712/1712 [==============================] - 0s 200us/step - loss: 1.5237e-04 - val_loss: 8.2664e-04
#
# Epoch 00066: val_loss did not improve from 0.00080
# Epoch 67/150
# 1712/1712 [==============================] - 0s 199us/step - loss: 1.5669e-04 - val_loss: 8.0566e-04
#
# Epoch 00067: val_loss did not improve from 0.00080
# Epoch 68/150
# 1712/1712 [==============================] - 0s 198us/step - loss: 1.5694e-04 - val_loss: 7.9710e-04
#
# Epoch 00068: val_loss improved from 0.00080 to 0.00080, saving model to best_weights.h5
# Epoch 69/150
# 1712/1712 [==============================] - 0s 193us/step - loss: 1.5486e-04 - val_loss: 9.0153e-04
#
# Epoch 00069: val_loss did not improve from 0.00080
# Epoch 70/150
# 1712/1712 [==============================] - 0s 205us/step - loss: 1.5682e-04 - val_loss: 7.9282e-04
#
# Epoch 00070: val_loss improved from 0.00080 to 0.00079, saving model to best_weights.h5
# Epoch 71/150
# 1712/1712 [==============================] - 0s 200us/step - loss: 1.5066e-04 - val_loss: 8.6392e-04
#
# Epoch 00071: val_loss did not improve from 0.00079
# Epoch 72/150
# 1712/1712 [==============================] - 0s 196us/step - loss: 1.5330e-04 - val_loss: 8.1147e-04
#
# Epoch 00072: val_loss did not improve from 0.00079
# Epoch 73/150
# 1712/1712 [==============================] - 0s 193us/step - loss: 1.5193e-04 - val_loss: 8.0636e-04
#
# Epoch 00073: val_loss did not improve from 0.00079
# Epoch 74/150
# 1712/1712 [==============================] - 0s 193us/step - loss: 1.4715e-04 - val_loss: 8.1844e-04
#
# Epoch 00074: val_loss did not improve from 0.00079
# Epoch 75/150
# 1712/1712 [==============================] - 0s 197us/step - loss: 1.4560e-04 - val_loss: 8.1177e-04
#
# Epoch 00075: val_loss did not improve from 0.00079
# Epoch 76/150
# 1712/1712 [==============================] - 0s 199us/step - loss: 1.4619e-04 - val_loss: 8.3475e-04
#
# Epoch 00076: val_loss did not improve from 0.00079
# Epoch 77/150
# 1712/1712 [==============================] - 0s 198us/step - loss: 1.4155e-04 - val_loss: 8.7383e-04
#
# Epoch 00077: val_loss did not improve from 0.00079
# Epoch 78/150
# 1712/1712 [==============================] - 0s 187us/step - loss: 1.4069e-04 - val_loss: 7.8745e-04
#
# Epoch 00078: val_loss improved from 0.00079 to 0.00079, saving model to best_weights.h5
# Epoch 79/150
# 1712/1712 [==============================] - 0s 190us/step - loss: 1.3941e-04 - val_loss: 8.3756e-04
#
# Epoch 00079: val_loss did not improve from 0.00079
# Epoch 80/150
# 1712/1712 [==============================] - 0s 191us/step - loss: 1.4074e-04 - val_loss: 8.1445e-04
#
# Epoch 00080: val_loss did not improve from 0.00079
# Epoch 81/150
# 1712/1712 [==============================] - 0s 200us/step - loss: 1.4018e-04 - val_loss: 8.1269e-04
#
# Epoch 00081: val_loss did not improve from 0.00079
# Epoch 82/150
# 1712/1712 [==============================] - 0s 198us/step - loss: 1.3991e-04 - val_loss: 8.2357e-04
#
# Epoch 00082: val_loss did not improve from 0.00079
# Epoch 83/150
# 1712/1712 [==============================] - 0s 200us/step - loss: 1.3111e-04 - val_loss: 8.4050e-04
#
# Epoch 00083: val_loss did not improve from 0.00079
# Epoch 84/150
# 1712/1712 [==============================] - 0s 188us/step - loss: 1.3069e-04 - val_loss: 8.2490e-04
#
# Epoch 00084: val_loss did not improve from 0.00079
# Epoch 85/150
# 1712/1712 [==============================] - 0s 188us/step - loss: 1.3309e-04 - val_loss: 8.7235e-04
#
# Epoch 00085: val_loss did not improve from 0.00079
# Epoch 86/150
# 1712/1712 [==============================] - 0s 190us/step - loss: 1.3001e-04 - val_loss: 8.0863e-04
#
# Epoch 00086: val_loss did not improve from 0.00079
# Epoch 87/150
# 1712/1712 [==============================] - 0s 192us/step - loss: 1.2894e-04 - val_loss: 7.7931e-04
#
# Epoch 00087: val_loss improved from 0.00079 to 0.00078, saving model to best_weights.h5
# Epoch 88/150
# 1712/1712 [==============================] - 0s 190us/step - loss: 1.3149e-04 - val_loss: 8.6295e-04
#
# Epoch 00088: val_loss did not improve from 0.00078
# Epoch 89/150
# 1712/1712 [==============================] - 0s 189us/step - loss: 1.3144e-04 - val_loss: 8.4495e-04
#
# Epoch 00089: val_loss did not improve from 0.00078
# Epoch 90/150
# 1712/1712 [==============================] - 0s 188us/step - loss: 1.2488e-04 - val_loss: 8.1170e-04
#
# Epoch 00090: val_loss did not improve from 0.00078
# Epoch 91/150
# 1712/1712 [==============================] - 0s 188us/step - loss: 1.2714e-04 - val_loss: 8.3318e-04
#
# Epoch 00091: val_loss did not improve from 0.00078
# Epoch 92/150
# 1712/1712 [==============================] - 0s 189us/step - loss: 1.2623e-04 - val_loss: 8.3891e-04
#
# Epoch 00092: val_loss did not improve from 0.00078
# Epoch 93/150
# 1712/1712 [==============================] - 0s 199us/step - loss: 1.2651e-04 - val_loss: 8.0165e-04
#
# Epoch 00093: val_loss did not improve from 0.00078
# Epoch 94/150
# 1712/1712 [==============================] - 0s 197us/step - loss: 1.2356e-04 - val_loss: 8.4014e-04
#
# Epoch 00094: val_loss did not improve from 0.00078
# Epoch 95/150
# 1712/1712 [==============================] - 0s 192us/step - loss: 1.2102e-04 - val_loss: 8.7423e-04
#
# Epoch 00095: val_loss did not improve from 0.00078
# Epoch 96/150
# 1712/1712 [==============================] - 0s 194us/step - loss: 1.2245e-04 - val_loss: 8.4704e-04
#
# Epoch 00096: val_loss did not improve from 0.00078
# Epoch 97/150
# 1712/1712 [==============================] - 0s 194us/step - loss: 1.1916e-04 - val_loss: 8.4099e-04
#
# Epoch 00097: val_loss did not improve from 0.00078
# Epoch 98/150
# 1712/1712 [==============================] - 0s 190us/step - loss: 1.2304e-04 - val_loss: 8.4904e-04
#
# Epoch 00098: val_loss did not improve from 0.00078
# Epoch 99/150
# 1712/1712 [==============================] - 0s 190us/step - loss: 1.1888e-04 - val_loss: 8.4020e-04
#
# Epoch 00099: val_loss did not improve from 0.00078
# Epoch 100/150
# 1712/1712 [==============================] - 0s 189us/step - loss: 1.2027e-04 - val_loss: 8.0046e-04
#
# Epoch 00100: val_loss did not improve from 0.00078
# Epoch 101/150
# 1712/1712 [==============================] - 0s 193us/step - loss: 1.2345e-04 - val_loss: 8.2197e-04
#
# Epoch 00101: val_loss did not improve from 0.00078
# Epoch 102/150
# 1712/1712 [==============================] - 0s 200us/step - loss: 1.1762e-04 - val_loss: 8.2244e-04
#
# Epoch 00102: val_loss did not improve from 0.00078
# Epoch 103/150
# 1712/1712 [==============================] - 0s 201us/step - loss: 1.1472e-04 - val_loss: 8.2000e-04
#
# Epoch 00103: val_loss did not improve from 0.00078
# Epoch 104/150
# 1712/1712 [==============================] - 0s 196us/step - loss: 1.1405e-04 - val_loss: 8.3545e-04
#
# Epoch 00104: val_loss did not improve from 0.00078
# Epoch 105/150
# 1712/1712 [==============================] - 0s 189us/step - loss: 1.1451e-04 - val_loss: 7.8872e-04
#
# Epoch 00105: val_loss did not improve from 0.00078
# Epoch 106/150
# 1712/1712 [==============================] - 0s 188us/step - loss: 1.1180e-04 - val_loss: 8.3709e-04
#
# Epoch 00106: val_loss did not improve from 0.00078
# Epoch 107/150
# 1712/1712 [==============================] - 0s 190us/step - loss: 1.1180e-04 - val_loss: 7.9070e-04
#
# Epoch 00107: val_loss did not improve from 0.00078
# Epoch 108/150
# 1712/1712 [==============================] - 0s 189us/step - loss: 1.1436e-04 - val_loss: 8.3527e-04
#
# Epoch 00108: val_loss did not improve from 0.00078
# Epoch 109/150
# 1712/1712 [==============================] - 0s 189us/step - loss: 1.1075e-04 - val_loss: 8.4994e-04
#
# Epoch 00109: val_loss did not improve from 0.00078
# Epoch 110/150
# 1712/1712 [==============================] - 0s 189us/step - loss: 1.0707e-04 - val_loss: 8.3079e-04
#
# Epoch 00110: val_loss did not improve from 0.00078
# Epoch 111/150
# 1712/1712 [==============================] - 0s 200us/step - loss: 1.0867e-04 - val_loss: 8.3069e-04
#
# Epoch 00111: val_loss did not improve from 0.00078
# Epoch 112/150
# 1712/1712 [==============================] - 0s 190us/step - loss: 1.0762e-04 - val_loss: 8.4974e-04
#
# Epoch 00112: val_loss did not improve from 0.00078
# Epoch 113/150
# 1712/1712 [==============================] - 0s 189us/step - loss: 1.0668e-04 - val_loss: 8.3728e-04
#
# Epoch 00113: val_loss did not improve from 0.00078
# Epoch 114/150
# 1712/1712 [==============================] - 0s 189us/step - loss: 1.0659e-04 - val_loss: 8.3241e-04
#
# Epoch 00114: val_loss did not improve from 0.00078
# Epoch 115/150
# 1712/1712 [==============================] - 0s 190us/step - loss: 1.0838e-04 - val_loss: 8.2940e-04
#
# Epoch 00115: val_loss did not improve from 0.00078
# Epoch 116/150
# 1712/1712 [==============================] - 0s 188us/step - loss: 1.0438e-04 - val_loss: 8.7042e-04
#
# Epoch 00116: val_loss did not improve from 0.00078
# Epoch 117/150
# 1712/1712 [==============================] - 0s 189us/step - loss: 1.0564e-04 - val_loss: 8.5437e-04
#
# Epoch 00117: val_loss did not improve from 0.00078
# Epoch 118/150
# 1712/1712 [==============================] - 0s 189us/step - loss: 1.0202e-04 - val_loss: 8.3167e-04
#
# Epoch 00118: val_loss did not improve from 0.00078
# Epoch 119/150
# 1712/1712 [==============================] - 0s 188us/step - loss: 1.0557e-04 - val_loss: 8.5174e-04
#
# Epoch 00119: val_loss did not improve from 0.00078
# Epoch 120/150
# 1712/1712 [==============================] - 0s 188us/step - loss: 1.0413e-04 - val_loss: 8.4337e-04
#
# Epoch 00120: val_loss did not improve from 0.00078
# Epoch 121/150
# 1712/1712 [==============================] - 0s 190us/step - loss: 9.9316e-05 - val_loss: 8.5416e-04
#
# Epoch 00121: val_loss did not improve from 0.00078
# Epoch 122/150
# 1712/1712 [==============================] - 0s 190us/step - loss: 1.0330e-04 - val_loss: 8.3883e-04
#
# Epoch 00122: val_loss did not improve from 0.00078
# Epoch 123/150
# 1712/1712 [==============================] - 0s 189us/step - loss: 9.9917e-05 - val_loss: 8.4394e-04
#
# Epoch 00123: val_loss did not improve from 0.00078
# Epoch 124/150
# 1712/1712 [==============================] - 0s 190us/step - loss: 1.0319e-04 - val_loss: 8.6547e-04
#
# Epoch 00124: val_loss did not improve from 0.00078
# Epoch 125/150
# 1712/1712 [==============================] - 0s 191us/step - loss: 1.0057e-04 - val_loss: 8.5104e-04
#
# Epoch 00125: val_loss did not improve from 0.00078
# Epoch 126/150
# 1712/1712 [==============================] - 0s 190us/step - loss: 9.8437e-05 - val_loss: 8.4278e-04
#
# Epoch 00126: val_loss did not improve from 0.00078
# Epoch 127/150
# 1712/1712 [==============================] - 0s 189us/step - loss: 1.0045e-04 - val_loss: 8.0480e-04
#
# Epoch 00127: val_loss did not improve from 0.00078
# Epoch 128/150
# 1712/1712 [==============================] - 0s 189us/step - loss: 1.0040e-04 - val_loss: 8.4401e-04
#
# Epoch 00128: val_loss did not improve from 0.00078
# Epoch 129/150
# 1712/1712 [==============================] - 0s 192us/step - loss: 9.9254e-05 - val_loss: 8.4139e-04
#
# Epoch 00129: val_loss did not improve from 0.00078
# Epoch 130/150
# 1712/1712 [==============================] - 0s 189us/step - loss: 9.5425e-05 - val_loss: 8.1633e-04
#
# Epoch 00130: val_loss did not improve from 0.00078
# Epoch 131/150
# 1712/1712 [==============================] - 0s 188us/step - loss: 9.7867e-05 - val_loss: 8.0286e-04
#
# Epoch 00131: val_loss did not improve from 0.00078
# Epoch 132/150
# 1712/1712 [==============================] - 0s 189us/step - loss: 9.9899e-05 - val_loss: 8.4875e-04
#
# Epoch 00132: val_loss did not improve from 0.00078
# Epoch 133/150
# 1712/1712 [==============================] - 0s 189us/step - loss: 9.5623e-05 - val_loss: 8.1695e-04
#
# Epoch 00133: val_loss did not improve from 0.00078
# Epoch 134/150
# 1712/1712 [==============================] - 0s 190us/step - loss: 9.3799e-05 - val_loss: 8.1155e-04
#
# Epoch 00134: val_loss did not improve from 0.00078
# Epoch 135/150
# 1712/1712 [==============================] - 0s 189us/step - loss: 9.5411e-05 - val_loss: 8.1815e-04
#
# Epoch 00135: val_loss did not improve from 0.00078
# Epoch 136/150
# 1712/1712 [==============================] - 0s 188us/step - loss: 9.3899e-05 - val_loss: 8.3864e-04
#
# Epoch 00136: val_loss did not improve from 0.00078
# Epoch 137/150
# 1712/1712 [==============================] - 0s 191us/step - loss: 9.5714e-05 - val_loss: 8.1886e-04
#
# Epoch 00137: val_loss did not improve from 0.00078
# Epoch 138/150
# 1712/1712 [==============================] - 0s 192us/step - loss: 9.9865e-05 - val_loss: 8.6176e-04
#
# Epoch 00138: val_loss did not improve from 0.00078
# Epoch 139/150
# 1712/1712 [==============================] - 0s 193us/step - loss: 9.6790e-05 - val_loss: 8.0855e-04
#
# Epoch 00139: val_loss did not improve from 0.00078
# Epoch 140/150
# 1712/1712 [==============================] - 0s 190us/step - loss: 9.3791e-05 - val_loss: 8.0745e-04
#
# Epoch 00140: val_loss did not improve from 0.00078
# Epoch 141/150
# 1712/1712 [==============================] - 0s 189us/step - loss: 9.0461e-05 - val_loss: 8.2023e-04
#
# Epoch 00141: val_loss did not improve from 0.00078
# Epoch 142/150
# 1712/1712 [==============================] - 0s 190us/step - loss: 8.9988e-05 - val_loss: 8.3076e-04
#
# Epoch 00142: val_loss did not improve from 0.00078
# Epoch 143/150
# 1712/1712 [==============================] - 0s 189us/step - loss: 9.0975e-05 - val_loss: 8.2487e-04
#
# Epoch 00143: val_loss did not improve from 0.00078
# Epoch 144/150
# 1712/1712 [==============================] - 0s 189us/step - loss: 9.2546e-05 - val_loss: 8.1690e-04
#
# Epoch 00144: val_loss did not improve from 0.00078
# Epoch 145/150
# 1712/1712 [==============================] - 0s 189us/step - loss: 9.0471e-05 - val_loss: 8.1840e-04
#
# Epoch 00145: val_loss did not improve from 0.00078
# Epoch 146/150
# 1712/1712 [==============================] - 0s 189us/step - loss: 9.1365e-05 - val_loss: 8.2373e-04
#
# Epoch 00146: val_loss did not improve from 0.00078
# Epoch 147/150
# 1712/1712 [==============================] - 0s 191us/step - loss: 8.7641e-05 - val_loss: 8.3559e-04
#
# Epoch 00147: val_loss did not improve from 0.00078
# Epoch 148/150
# 1712/1712 [==============================] - 0s 190us/step - loss: 8.7978e-05 - val_loss: 8.0945e-04
#
# Epoch 00148: val_loss did not improve from 0.00078
# Epoch 149/150
# 1712/1712 [==============================] - 0s 189us/step - loss: 8.8221e-05 - val_loss: 8.2274e-04
#
# Epoch 00149: val_loss did not improve from 0.00078
# Epoch 150/150
# 1712/1712 [==============================] - 0s 191us/step - loss: 8.7495e-05 - val_loss: 8.1717e-04
#
# Epoch 00150: val_loss did not improve from 0.00078

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %% [markdown]
# ### 觀察 model 在 testing 上的結果

# %%
# 讀取測試資料集
imgs_test, _ = load_data(dirname = 'G:/GitHub/CVDL/data/test/test.csv')

# %%
# 在灰階圖像上畫關鍵點的函數
def plot_keypoints(img, points):
    plt.imshow(img, cmap='gray')
    for i in range(0,30,2):
        plt.scatter((points[i] + 0.5)*96, (points[i+1]+0.5)*96, color='red')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_predict = model.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_predict[i]))

# %% [markdown]
# 目前為止，大致可以觀察到，直接使用簡單的模型以及訓練方式在這組數據上應該可以在訓練集和測試集上都得到一個還不錯的結果，說明這組資料其實不會很難。

# %% [markdown]
# img = cv2.imread('G:/GitHub/CVDL/data/Tano.JPG')
# img = cv2.resize(img, (224,224))##改變圖片尺寸
# img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) #Cv2讀進來是BGR，轉成RGB
# img_origin=img.copy()
# img= np.array(img, dtype=np.float32)
#
# images = np.random.randint(0, 255, (5, 224, 224, 3), dtype=np.uint8)##創造一個array size==(5, 224, 224, 3)
#
# flipper = iaa.Fliplr(1.0) #水平翻轉機率==1.0
# images[0] = flipper.augment_image(img)
#
# vflipper = iaa.Flipud(0.4) #垂直翻轉機率40%
# images[1] = vflipper.augment_image(img)
#
# blurer = iaa.GaussianBlur(3.0)
# images[2] = blurer.augment_image(img) # 高斯模糊圖像( sigma of 3.0)
#
# translater = iaa.Affine(translate_px={"x": -16}) #向左橫移16個像素
# images[3] = translater.augment_image(img)
#
# scaler = iaa.Affine(scale={"y":(0.8,1.2)}) # 縮放照片，區間(0.8-1.2倍)
# images[4] = scaler.augment_image(img)
#
# i=1
# plt.figure(figsize=(20,20))
# for image in images:
#     plt.subplot(1, 6, 1)
#     plt.imshow(img_origin.astype(np.uint8))
#     plt.subplot(1, 6, i+1)
#     plt.imshow(image.astype(np.uint8))
#     plt.axis('off')
#     i+=1

# %%
model_with_augment = get_model()
model_with_augment.compile(loss='mean_squared_error', optimizer='adam')

# %%
# Your code
import imgaug as ia
import imgaug.augmenters as iaa
from imgaug.augmentables.kps import Keypoint, KeypointsOnImage
import cv2
import random

# %%
def augment(img, points):
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) #Cv2讀進來是BGR，轉成RGB
    img= np.array(img, dtype=np.float32)

    kps = [
    Keypoint(x=points[0], y=points[1]),  # 'left_eye_center_x', 'left_eye_center_y'
    Keypoint(x=points[2], y=points[3]),  # 'right_eye_center_x', 'right_eye_center_y', 
    Keypoint(x=points[4], y=points[5]),  # 'left_eye_inner_corner_x', 'left_eye_inner_corner_y',
    Keypoint(x=points[6], y=points[7]),  # 'left_eye_outer_corner_x', 'left_eye_outer_corner_y', 
    Keypoint(x=points[8], y=points[9]),  # 'right_eye_inner_corner_x', 'right_eye_inner_corner_y', 
    Keypoint(x=points[10], y=points[11]), # 'right_eye_outer_corner_x', 'right_eye_outer_corner_y',
    Keypoint(x=points[12], y=points[13]), # 'left_eyebrow_inner_end_x', 'left_eyebrow_inner_end_y', 
    Keypoint(x=points[14], y=points[15]), # 'left_eyebrow_outer_end_x', 'left_eyebrow_outer_end_y',
    Keypoint(x=points[16], y=points[17]), # 'right_eyebrow_inner_end_x', 'right_eyebrow_inner_end_y',
    Keypoint(x=points[18], y=points[19]), # 'right_eyebrow_outer_end_x', 'right_eyebrow_outer_end_y', 
    Keypoint(x=points[20], y=points[21]), # 'nose_tip_x', 'nose_tip_y',
    Keypoint(x=points[22], y=points[23]), # 'mouth_left_corner_x', 'mouth_left_corner_y', 
    Keypoint(x=points[24], y=points[25]), # 'mouth_right_corner_x', 'mouth_right_corner_y'
    Keypoint(x=points[26], y=points[27]), # 'mouth_center_top_lip_x', 'mouth_center_top_lip_y',
    Keypoint(x=points[28], y=points[29])  # 'mouth_center_bottom_lip_x', 'mouth_center_bottom_lip_y'
    ]
    kpsoi = KeypointsOnImage(kps, shape=img.shape)
    sometimes = lambda aug: iaa.Sometimes(0.5, aug) # Sometimes(0.5, ...) 代表每次都有50%的機率運用不同的Augmentation

    ##包裝想運用之圖像強化方式
    seq = iaa.Sequential([
        iaa.Fliplr(0.5), # horizontally flip 50% of the images
        iaa.Flipud(0.5), # vertically flip 50% of all images
        #iaa.GaussianBlur(sigma=(0, 3.0)), # blur images with a sigma of 0 to 3.0
        iaa.Affine(
                scale={"x": (0.8, 1.2), "y": (0.8, 1.2)}, # scale images to 80-120% of their size, individually per axis
                translate_px={"x": (-16, 16), "y": (-16, 16)}, # translate by -16 to +16 pixels (per axis)
                rotate=(-45, 45), # rotate by -45 to +45 degrees
                shear=(-16, 16), # shear by -16 to +16 degrees
                order=ia.ALL, # use any of scikit-image's interpolation methods
                #cval=(0, 1.0), # if mode is constant, use a cval between 0 and 1.0
                #mode=ia.ALL # use any of scikit-image's warping modes (see 2nd image from the top for examples)
            )
        ],
        random_order=True # do all of the above in random order
    )
    
    
    #image_aug = seq.augment_images(img) ## Image Augmentation
    image_aug, kps_aug = seq(image=img, keypoints=kpsoi) # Image Augmentation
    #for i in range(len(kpsoi.keypoints)):
    #    kps_before = kpsoi.keypoints[i]
    #    kps_after = kps_aug.keypoints[i]
        #print("Keypoint %d: (%.8f, %.8f) -> (%.8f, %.8f)" % (i, kps_before.x, kps_before.y, kps_after.x, kps_after.y))

    return image_aug, kps_aug

# %%
imgs_train.shape
# Out:
# (2140, 96, 96)

# %%
plt.imshow(imgs_train[0], cmap='gray')

# %%
img_aug, point_aug = augment(imgs_train[0], points_train[0])
#ia.imshow(kpsoi.draw_on_image(img_aug, size=7))
ia.imshow(point_aug.draw_on_image(img_aug, color=(255, 0, 0), size=7))

# %%
for i in range(len(point_aug.keypoints)):
    print(point_aug.keypoints[i])
# Out:
# Keypoint(x=-10.57457924, y=-10.79163456)
# Keypoint(x=-11.02216148, y=-10.82747650)
# Keypoint(x=-10.65522385, y=-10.78267384)
# Keypoint(x=-10.48587036, y=-10.77819443)
# Keypoint(x=-10.94554329, y=-10.81403542)
# Keypoint(x=-11.10683823, y=-10.81403542)
# Keypoint(x=-10.68808365, y=-10.93008804)
# Keypoint(x=-10.39716148, y=-10.88572025)
# Keypoint(x=-10.89715385, y=-10.93052292)
# Keypoint(x=-11.19554520, y=-10.92156315)
# Keypoint(x=-10.84474373, y=-10.54073906)
# Keypoint(x=-10.63505936, y=-10.22263718)
# Keypoint(x=-11.04231834, y=-10.25848675)
# Keypoint(x=-10.85859299, y=-10.32034111)
# Keypoint(x=-10.86086655, y=-10.15991974)
